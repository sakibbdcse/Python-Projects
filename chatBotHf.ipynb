# %%
# !nvidia-smi
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !huggingface-cli login
# Out:
# ^C

# %%
from langchain.llms import HuggingFacePipeline

# %%
from transformers import AutoTokenizer

# %%
import transformers

# %%
import torch

# %%
model = "daryl149/llama-2-7b-chat-hf"

# %%
tokenizer = AutoTokenizer.from_pretrained(model)

# %%
pipeline = transformers.pipeline(
    "text-generation",
    model = model,
    tokenizer = tokenizer,
    torch_dtype = torch.bfloat16,
    trust_remote_code = True,
    device_map = "auto",
    max_length = 1000,
    do_sample = True,
    top_k = 10,
    num_return_sequences =1,
    eos_token_id = tokenizer.eos_token_id
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 18
#      15 offload_folder = "./offload_weights"
#      16 os.makedirs(offload_folder, exist_ok=True)
# ---> 18 pipeline = transformers.pipeline(
#      19     "text-generation",
#      20     model=model,
#      21     tokenizer=tokenizer,
#      22     torch_dtype=torch.bfloat16,
#      23     device_map="auto",
#      24     offload_folder=offload_folder,  # Specify folder for offloaded weights
#      25     max_length=1000,
#      26     do_sample=True,
#      27     top_k=10,
#      28     num_return_sequences=1,
#      29     eos_token_id=tokenizer.eos_token_id
#      30 )
#
# File d:\Sofrware develompment\Python-Projects\ENV\Lib\site-packages\transformers\pipelines\__init__.py:926, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     924 if isinstance(model, str) or framework is None:
#     925     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 926     framework, model = infer_framework_load_model(
#     927         model,
#     928         model_classes=model_classes,
#     929         config=config,
#     930         framework=framework,
#     931         task=task,
#     932         **hub_kwargs,
#     933         **model_kwargs,
#     934     )
#     936 model_config = model.config
#     937 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File d:\Sofrware develompment\Python-Projects\ENV\Lib\site-packages\transformers\pipelines\base.py:302, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     300         for class_name, trace in all_traceback.items():
#     301             error += f"while loading with {class_name}, an error is thrown:\n{trace}\n"
# --> 302         raise ValueError(
#     303             f"Could not load model {model} with any of the following classes: {class_tuple}. See the original errors:\n\n{error}\n"
#     304         )
#     306 if framework is None:
#     307     framework = infer_framework(model.__class__)
#
# ValueError: Could not load model daryl149/llama-2-7b-chat-hf with any of the following classes: (<class 'transformers.models.auto.modeling_auto.AutoModelForCausalLM'>, <class 'transformers.models.llama.modeling_llama.LlamaForCausalLM'>). See the original errors:
#
# while loading with AutoModelForCausalLM, an error is thrown:
# Traceback (most recent call last):
#   File "d:\Sofrware develompment\Python-Projects\ENV\Lib\site-packages\transformers\pipelines\base.py", line 289, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Sofrware develompment\Python-Projects\ENV\Lib\site-packages\transformers\models\auto\auto_factory.py", line 564, in from_pretrained
#     return model_class.from_pretrained(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Sofrware develompment\Python-Projects\ENV\Lib\site-packages\transformers\modeling_utils.py", line 4225, in from_pretrained
#     ) = cls._load_pretrained_model(
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Sofrware develompment\Python-Projects\ENV\Lib\site-packages\transformers\modeling_utils.py", line 4361, in _load_pretrained_model
#     raise ValueError(
# ValueError: The current `device_map` had weights offloaded to the disk. Please provide an `offload_folder` for them. Alternatively, make sure you have `safetensors` installed if the model you are using offers the weights in this format.
#
# while loading with LlamaForCausalLM, an error is thrown:
# Traceback (most recent call last):
#   File "d:\Sofrware develompment\Python-Projects\ENV\Lib\site-packages\transformers\pipelines\base.py", line 289, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Sofrware develompment\Python-Projects\ENV\Lib\site-packages\transformers\modeling_utils.py", line 4225, in from_pretrained
#     ) = cls._load_pretrained_model(
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Sofrware develompment\Python-Projects\ENV\Lib\site-packages\transformers\modeling_utils.py", line 4361, in _load_pretrained_model
#     raise ValueError(
# ValueError: The current `device_map` had weights offloaded to the disk. Please provide an `offload_folder` for them. Alternatively, make sure you have `safetensors` installed if the model you are using offers the weights in this format.

# %%
llm = HuggingFacePipeline(pipeline=pipeline, model_kwargs={'temperature':0})

# %%
prompt ="tell me a company name it uniqe"

# %%
print(llm(prompt))
# Out:
# tell me a company name it uniqe and relevant to your business
# A company name that is both unique and relevant to the business is essential in creating a lasting impression in the marketplace. Here are a few suggestions for a unique and relevant company name:
# 1. "Nexus Innovations" - This name suggests a connection or link between different ideas, technologies, or industries, which can be fitting for a business that specializes in bringing innovative solutions to the market.
# 2. "Pulse Tech Solutions" - This name plays on the idea of a "pulse" or a strong, steady beat, which can represent the company's commitment to delivering cutting-edge technology solutions that help drive business forward.
# 3. "Cerebra Solutions" - The name "Cerebra" is derived from the Latin word for "brain," which can symbolize the company's focus on developing intelligent and innovative solutions that are designed to improve business outcomes.
# 4. "Elevate Digital" - This name conveys the idea of taking businesses to new heights through digital transformation and innovation, while also being easy to remember and pronounce.
# 5. "Velocity Labs" - The name "Velocity" suggests speed and agility, which can be fitting for a business that specializes in driving innovation and digital transformation in the marketplace.
# 6. "Fusion Studio" - This name plays on the idea of fusion, which can represent the bringing together of different ideas, technologies, or industries to create something new and innovative.
# 7. "Zenith Digital" - The name "Zenith" refers to the highest point or apex of something, which can be fitting for a business that aims to help businesses reach new heights of success through digital transformation.
# 8. "Apex Solutions" - This name conveys the idea of reaching new heights or apexes of success, which can be fitting for a business that specializes in delivering innovative solutions that help businesses achieve their goals.
# 9. "Nexus Point" - The name "Nexus Point" suggests a connection or link between different ideas, technologies, or industries, which can be fitting for a business that specializes in bringing innovative solutions to the market.
# 10. "Prodigy Solutions" - The name "Prodigy" refers to someone who is exceptionally talented or gifted, which can be fitting for a business that aims to provide innovative solutions that help businesses achieve their goals.
# I hope these suggestions help you find the perfect name for your business!

# %%
from langchain.prompts import PromptTemplate
